# %% [markdown]
# # 4.3.2 데이터세트 및
# # 4.3.4 파이선 연관 분석

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Book2/Ch4/basket_analysis.csv')
df.shape
# Out:
# (999, 17)

# %%
df.head(3)
# Out:
#    Unnamed: 0  Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0           0  False   True   False   False   True   True  False       True
# 1           1  False  False   False   False  False  False  False      False
# 2           2   True  False    True   False  False   True  False       True
#
#    Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0         False  False   False  False   True    False    True       True
# 1         False   True   False  False  False    False   False      False
# 2         False   True   False  False  False    False    True       True

# %%
# Unnamed: 0 컬럼 제거
df = df.drop('Unnamed: 0',axis=1)
df.head(3)
# Out:
#    Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  Kidney Beans  \
# 0  False   True   False   False   True   True  False       True         False
# 1  False  False   False   False  False  False  False      False         False
# 2   True  False    True   False  False   True  False       True         False
#
#     Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0  False   False  False   True    False    True       True
# 1   True   False  False  False    False   False      False
# 2   True   False  False  False    False    True       True

# %%
df1 = df.replace(True, 1).replace(False, "")   # True를 1로, False를 결측값으로 변환
df1.head(3)
# Out:
#   Apple Bread Butter Cheese Corn Dill Eggs Ice cream Kidney Beans Milk Nutmeg  \
# 0           1                  1    1              1
# 1                                                                    1
# 2     1            1                1              1                 1
#
#   Onion Sugar Unicorn Yogurt chocolate
# 0           1              1         1
# 1
# 2                          1         1

# %%
# 데이터프레임 df1를 구글 클라우드 지정 경로에 basket_analysis_number.csv 파일명으로 저장
df1.to_csv('/content/drive/MyDrive/Colab Notebooks/Book2/Ch4/basket_analysis_number.csv', index=False)

# %%
df.head(3)
# Out:
#    Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  Kidney Beans  \
# 0  False   True   False   False   True   True  False       True         False
# 1  False  False   False   False  False  False  False      False         False
# 2   True  False    True   False  False   True  False       True         False
#
#     Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0  False   False  False   True    False    True       True
# 1   True   False  False  False    False   False      False
# 2   True   False  False  False    False    True       True

# %%
# mlxtend 라이브러리에서 apriori, association_rules 기능 import 
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.filterwarnings('ignore')

# %%
# Apriori 알고리듬을 통해 Frequent Itemsets 계산
# 오렌지3 Frequent Itemsets 환경설정과 동일하게 설정
frequent_itemsets = apriori(df,
                            min_support = .01,
                            max_len = 6,
                            use_colnames = True)

# %%
# Frequent Itemset를 support값에 따라 sort 후 첫 5행까지 디스플레이
frequent_itemsets.sort_values(by=['support']).head()
# Out:
#       support                                           itemsets
# 9415  0.01001  (Unicorn, Kidney Beans, Bread, Sugar, Corn, Eggs)
# 7924  0.01001       (Cheese, Unicorn, Apple, Dill, Nutmeg, Eggs)
# 7930  0.01001         (Yogurt, Cheese, Apple, Dill, Sugar, Eggs)
# 7934  0.01001  (Cheese, Milk, Apple, Kidney Beans, Dill, Ice ...
# 7936  0.01001  (Cheese, Apple, Kidney Beans, Dill, Ice cream,...

# %%
# Frequent_Itemsets를 대상으로 연관 규칙(Association rule) 생성 
rules = association_rules(frequent_itemsets,
                            metric = 'support',
                            min_threshold=0.01)

# %%
rules.shape
# Out:
# (473170, 9)

# %%
rules
# Out:
#         antecedents                                  consequents  \
# 0           (Bread)                                      (Apple)
# 1           (Apple)                                      (Bread)
# 2          (Butter)                                      (Apple)
# 3           (Apple)                                     (Butter)
# 4          (Cheese)                                      (Apple)
# ...             ...                                          ...
# 473165    (Unicorn)    (Yogurt, Nutmeg, Sugar, Onion, chocolate)
# 473166     (Nutmeg)   (Yogurt, Unicorn, Sugar, Onion, chocolate)
# 473167      (Sugar)  (Yogurt, Unicorn, Nutmeg, Onion, chocolate)
# 473168      (Onion)  (Yogurt, Unicorn, Nutmeg, Sugar, chocolate)
# 473169  (chocolate)      (Yogurt, Unicorn, Nutmeg, Sugar, Onion)
#
#         antecedent support  consequent support   support  confidence  \
# 0                 0.384384            0.383383  0.154154    0.401042
# 1                 0.383383            0.384384  0.154154    0.402089
# 2                 0.420420            0.383383  0.188188    0.447619
# 3                 0.383383            0.420420  0.188188    0.490862
# 4                 0.404404            0.383383  0.162162    0.400990
# ...                    ...                 ...       ...         ...
# 473165            0.389389            0.023023  0.012012    0.030848
# 473166            0.401401            0.026026  0.012012    0.029925
# 473167            0.409409            0.026026  0.012012    0.029340
# 473168            0.403403            0.022022  0.012012    0.029777
# 473169            0.421421            0.022022  0.012012    0.028504
#
#             lift  leverage  conviction
# 0       1.046059  0.006788    1.029482
# 1       1.046059  0.006788    1.029610
# 2       1.167549  0.027006    1.116289
# 3       1.167549  0.027006    1.138354
# 4       1.045925  0.007120    1.029393
# ...          ...       ...         ...
# 473165  1.339890  0.003047    1.008074
# 473166  1.149818  0.001565    1.004019
# 473167  1.127327  0.001357    1.003414
# 473168  1.352132  0.003128    1.007993
# 473169  1.294321  0.002731    1.006672
#
# [473170 rows x 9 columns]

# %%
c1 = rules['confidence'] > 0.85   # 조건 C1 생성
filtered_rules = rules[c1]        # 조건 C1을 만족하는 연관 규칙 필터링
filtered_rules.shape
# Out:
# (36, 9)

# %%
# support 변수 기준으로 내림차순 정렬
filtered_rules.sort_values(by=['support'],ascending=False)
# Out:
#                                            antecedents     consequents  \
# 287050             (Milk, Bread, Butter, Nutmeg, Corn)  (Kidney Beans)
# 321211            (Milk, Unicorn, Bread, Nutmeg, Corn)  (Kidney Beans)
# 249164      (Unicorn, Apple, Ice cream, Nutmeg, Sugar)          (Corn)
# 246871           (Unicorn, Apple, Nutmeg, Sugar, Eggs)          (Corn)
# 223124         (Cheese, Unicorn, Apple, Nutmeg, Sugar)          (Corn)
# 287174              (Milk, Bread, Butter, Sugar, Corn)  (Kidney Beans)
# 253815      (Unicorn, Apple, Nutmeg, Sugar, chocolate)          (Corn)
